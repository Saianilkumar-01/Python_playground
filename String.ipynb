# %%
message = 'sai\'s anil kumar' # while using single quotes, we need to escape the single quote in the string using a backslash (\)
print(message)
# Out:
# sai's anil kumar

# %%
msg = "543"

print(msg.isdecimal())
